# %%
# import the required packages for the execution of the program
import pandas as pd
import numpy as np
import tweepy
import json
from geopy.geocoders import Nominatim
import time
import textblob
import re

# %%
# save the twitter developer credentials for authentication
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
# initialize authorization instance using credentials
authorization_instance = tweepy.OAuthHandler(consumer_key,consumer_secret)
authorization_instance.set_access_token(access_token, access_token_secret)
authorization_instance.secure = True

# %%
# initialize the twitter API object
twitter_api = tweepy.API(authorization_instance)
twitter_api

# %%
# create a twitter stream listerner from the class provided by tweepy
class MyStreamListener(tweepy.StreamListener):
    def __init__(self,time_limit=60,count_limit = 10):
        self.start_time = time.time()
        self.count_limit = count_limit # restrict the number of tweets
        self.time_limit = time_limit  # restrict the time of streaming
        self.tweet_list = []
        self.count = 0
        self.output_file  = open('./logs.txt', 'w',encoding='utf-8') # open a csv file to save tweet logs
    
    def on_data(self, data):
        if (self.count_limit is not None and self.count >= self.count_limit): # check the tweet count
            self.output_file.close() # close the file
            return False
        elif (self.time_limit is not None) and ((time.time() - self.start_time) > self.time_limit): # check the time limit
            self.output_file.close()
            return False
        else:        
            self.count += 1
            json_data = json.loads(data)
            user_name = json_data['user']['screen_name']
            text = json_data['text']
            time_stamp = json_data['created_at']

            #self.tweet_list.append(text)

            self.output_file.write(''+'Tweet Count:'+str(self.count) +'\n'
                                   +'User Name:'+ user_name + '\n' 
                                   +'Tweet:'+text + '\n'
                                   +'Time Stamp:'+str(time_stamp) + '\n'
                                  +'===================================================< \n') # write the log to the csv file
            print('Tweet count:',self.count)
            #print(user_name,'==>',text,'<==',time_stamp,'\n') 
            return True
    
    def on_error(self, status):
        print(status)
    
    def on_timeout(self):
        print('Timeout...')
        return True
    
    def on_connect(self):
        print('Streaming is ON...')
    
    def on_disconnect(self):
        print('Streaming is disconnected...')
    
    def on_limit(self):
        print('Limit is crossed...')

# %%
# create a stream listener object with 'time_limit' seconds restriction
my_stream_listener = MyStreamListener(time_limit = 10, count_limit = 100)
twitter_streamer = tweepy.Stream(auth=twitter_api.auth,
                                listener = my_stream_listener,
                                tweet_mode='extended_tweet')

#specify a list of topics you are interested in 
topic_list = ['trump']
twitter_streamer.filter(track= topic_list,
                        async=False,
                        languages=['en'])
# Out:
# Streaming is ON...
# Tweet count: 1
# Tweet count: 2
# Tweet count: 3
# Tweet count: 4
# Tweet count: 5
# Tweet count: 6
# Tweet count: 7
# Tweet count: 8
# Tweet count: 9
# Tweet count: 10
# Tweet count: 11
# Tweet count: 12
# Tweet count: 13
# Tweet count: 14
# Tweet count: 15
# Tweet count: 16
# Tweet count: 17
# Tweet count: 18
# Tweet count: 19
# Tweet count: 20
# Tweet count: 21
# Tweet count: 22
# Tweet count: 23
# Tweet count: 24
# Tweet count: 25
# Tweet count: 26
# Tweet count: 27
# Tweet count: 28
# Tweet count: 29
# Tweet count: 30
# Tweet count: 31
# Tweet count: 32
# Tweet count: 33
# Tweet count: 34
# Tweet count: 35
# Tweet count: 36
# Tweet count: 37
# Tweet count: 38
# Tweet count: 39
# Tweet count: 40
# Tweet count: 41
# Tweet count: 42
# Tweet count: 43
# Tweet count: 44
# Tweet count: 45
# Tweet count: 46
# Tweet count: 47
# Tweet count: 48
# Tweet count: 49
# Tweet count: 50
# Tweet count: 51
# Tweet count: 52
# Tweet count: 53
# Tweet count: 54
# Tweet count: 55
# Tweet count: 56
# Tweet count: 57
# Tweet count: 58
# Tweet count: 59
# Tweet count: 60
# Tweet count: 61
# Tweet count: 62
# Tweet count: 63
# Tweet count: 64
# Tweet count: 65
# Tweet count: 66
# Tweet count: 67
# Tweet count: 68
# Tweet count: 69
# Tweet count: 70
# Tweet count: 71
# Tweet count: 72
# Tweet count: 73
# Tweet count: 74
# Tweet count: 75
# Tweet count: 76
# Tweet count: 77

# %%
# print the tweet data saved in the file
f = open("./logs.txt","r", encoding="utf-8")
for line in f:
    print(line)
# Out:
# Tweet Count:1
#
# User Name:southernCAsolar
#
# Tweet:Top story: Donald J. Trump on Twitter: "Fire at Trump Tower is out. Very confin… https://t.co/IyDIsoe8QQ, see more https://t.co/jNr5f9z0Jm
#
# Time Stamp:Sun Apr 08 08:52:08 +0000 2018
#
# ===================================================<
#
# Tweet Count:2
#
# User Name:MeldeLawrence
#
# Tweet:RT @cswany2: @pjboon60 @TEN_G0P You take any group of people.
#
# 20% are Saints
#
# 20% are pure evil
#
# 60% show up and go with the flow
#
# Whatever d…
#
# Time Stamp:Sun Apr 08 08:52:08 +0000 2018
#
# ===================================================<
#
# Tweet Count:3
#
# User Name:JCollaro
#
# Tweet:RT @ddale8: The president boasted about the quality of his building in his sole statement on a fire that killed a man he hasn’t mentioned.…
#
# Time Stamp:Sun Apr 08 08:52:08 +0000 2018
#
# ===================================================<
#
# Tweet Count:4
#
# User Name:Le_Phonz
#
# Tweet:RT @TheDweck: A person in his building died and he’s    bragging about the building https://t.co/OKA7Hbf12L
#
# Time Stamp:Sun Apr 08 08:52:08 +0000 2018
#
# ===================================================<
#
# Tweet Count:5
#
# User Name:onlyjohnvern
#
# Tweet:RT @piscesangel: he probably blasted 'Anna Wintour' https://t.co/GQ4QlRWf5F
#
# Time Stamp:Sun Apr 08 08:52:08 +0000 2018
#
# ===================================================<
#
# Tweet Count:6
#
# User Name:GlobalMuffins
#
# Tweet:RT @joshgad: When I grow up, I want to be Ivanka’s clothing line. It’s treated better than dreamers, immigrants, gays, transgender troops,…
#
# Time Stamp:Sun Apr 08 08:52:09 +0000 2018
#
# ===================================================<
#
# Tweet Count:7
#
# User Name:AlexAloha67
#
# Tweet:RT @AlexAloha67: #MAGA #Trump #StormyDanielsDay #StormyDaniels #ObamaGate #FBICorruption #UraniumOne #Dossier #DeepStateGate #DrainTheDeepS…
#
# Time Stamp:Sun Apr 08 08:52:09 +0000 2018
#
# ===================================================<
#
# Tweet Count:8
#
# User Name:JJaazzee1
#
# Tweet:RT @brycetache: It’s weird. I just caught up on a week of news after being on vacation. I thought I’d feel angry &amp; overwhelmed. But no, I f…
#
# Time Stamp:Sun Apr 08 08:52:09 +0000 2018
#
# ===================================================<
#
# Tweet Count:9
#
# User Name:Sarah89847810
#
# Tweet:Wait. So, @NRA thinks gun registration is a violation of rights, but a #Murdering #Torturing bish, collecting outsp… https://t.co/dDrldE8kZR
#
# Time Stamp:Sun Apr 08 08:52:09 +0000 2018
#
# ===================================================<
#
# Tweet Count:10
#
# User Name:Alinapoddig
#
# Tweet:RT @NYPDnews: Due to a fire at Trump Tower  #Manhattan, expect police and @FDNY in the area of 5th Ave/W.57 St. Expect traffic and street c…
#
# Time Stamp:Sun Apr 08 08:52:09 +0000 2018
#
# ===================================================<
#
# Tweet Count:11
#
# User Name:chirprn
#
# Tweet:RT @krassenstein: If you are going to get mad at Jimmy Kimmel for barely insulting Melania Trump then you better be furious at the Presiden…
#
# Time Stamp:Sun Apr 08 08:52:09 +0000 2018
#
# ===================================================<
#
# Tweet Count:12
#
# User Name:Patrici71676542
#
# Tweet:RT @Pink_About_it: Snoop dogg makes a trump assassination video
#
#
#
# Eminem makes a music video about assassinating Ivanka Trump
#
#
#
# These are t…
#
# Time Stamp:Sun Apr 08 08:52:10 +0000 2018
#
# ===================================================<
#
# Tweet Count:13
#
# User Name:ghiamia73
#
# Tweet:@ItsMeCathi @alltht4u @realDonaldTrump Trump's penthouse is on floors labeled 66 through 68, The tower really has 5… https://t.co/IUiPmWGiam
#
# Time Stamp:Sun Apr 08 08:52:10 +0000 2018
#
# ===================================================<
#
# Tweet Count:14
#
# User Name:outerspacemanII
#
# Tweet:RT @dionlisle: We are not being invaded by Mexico. Send the national guard to Puerto Rico to help them get water and power. Maybe to Flint…
#
# Time Stamp:Sun Apr 08 08:52:10 +0000 2018
#
# ===================================================<
#
# Tweet Count:15
#
# User Name:I_News_N
#
# Tweet:1 Man Killed In condominium hearth At Trump Tower In NY city -- #1 #Man #Killed #In #condominium #hearth #At #Trum.… https://t.co/6MfGC1VBqQ
#
# Time Stamp:Sun Apr 08 08:52:10 +0000 2018
#
# ===================================================<
#
# Tweet Count:16
#
# User Name:rnvandy65
#
# Tweet:RT @ElderLansing: A man died in Trump Tower in a vicious fire yet Libnuts and some Never Trumpers are making jokes about it. These are sick…
#
# Time Stamp:Sun Apr 08 08:52:10 +0000 2018
#
# ===================================================<
#
# Tweet Count:17
#
# User Name:yoshiandpeanut
#
# Tweet:RT @TheGoodGodAbove: Trump said he would've run into Parkland High School to stop the shooter even if he was unarmed.
#
#
#
# But he's too afraid…
#
# Time Stamp:Sun Apr 08 08:52:10 +0000 2018
#
# ===================================================<
#
# Tweet Count:18
#
# User Name:kaz334
#
# Tweet:Such a talented horse🙈HK Racing’s loveable rogue #PakistanStar https://t.co/DXox6tITTM
#
# Time Stamp:Sun Apr 08 08:52:10 +0000 2018
#
# ===================================================<
#
# Tweet Count:19
#
# User Name:Daniel_pastrami
#
# Tweet:This chapter name in my history book is a great metaphor for trump https://t.co/rFvdmEGlYj
#
# Time Stamp:Sun Apr 08 08:52:10 +0000 2018
#
# ===================================================<
#
# Tweet Count:20
#
# User Name:see_jl
#
# Tweet:RT @RealEagleBites: After spying on millions of users, Facebook now admits that it discriminates against African-Americans who DARE to expr…
#
# Time Stamp:Sun Apr 08 08:52:08 +0000 2018
#
# ===================================================<
#
# Tweet Count:21
#
# User Name:TrumpsDC
#
# Tweet:@Shawtypepelina They talk sh*t because they're TERRIFIED of Trump and his Army of American Patriots. Makes me feel… https://t.co/iIPxmcdBbf
#
# Time Stamp:Sun Apr 08 08:52:10 +0000 2018
#
# ===================================================<
#
# Tweet Count:22
#
# User Name:mkg_sd
#
# Tweet:RT @MollyJongFast: Well, there’s one immigrant that the maga crowd defends. https://t.co/VOAeiX9bNZ
#
# Time Stamp:Sun Apr 08 08:52:10 +0000 2018
#
# ===================================================<
#
# Tweet Count:23
#
# User Name:ClarisseBlack
#
# Tweet:RT @DalinRP: Thank you,  Sean, for being a gentleman and standing up for our beautiful,kind and classy first lady.
#
#
#
# #FLOTUS
#
# #Istandwithha…
#
# Time Stamp:Sun Apr 08 08:52:11 +0000 2018
#
# ===================================================<
#
# Tweet Count:24
#
# User Name:Didi_Andreundi
#
# Tweet:Exclusive: President Trump has begun informally preparing for a possible interview with special counsel Robert Muel… https://t.co/EDDDRkTeQt
#
# Time Stamp:Sun Apr 08 08:52:11 +0000 2018
#
# ===================================================<
#
# Tweet Count:25
#
# User Name:tomannynot
#
# Tweet:RT @joshtpm: Trump Tower alarm system seems to leave a bit to be desired https://t.co/pCyAKkf52X https://t.co/mtGcmk8xDU
#
# Time Stamp:Sun Apr 08 08:52:11 +0000 2018
#
# ===================================================<
#
# Tweet Count:26
#
# User Name:Insidze
#
# Tweet:RT @Clairety_AI: Our AI read Donald Trump's Twitter Feed to Rate his 'Credibility'.  Here's our CEO discussing what happened.  Learn more a…
#
# Time Stamp:Sun Apr 08 08:52:11 +0000 2018
#
# ===================================================<
#
# Tweet Count:27
#
# User Name:KaraMNY
#
# Tweet:RT @jimmykimmel: When your clown makeup rubs off on Trump’s ass, does it make his butt look like a Creamsicle? https://t.co/DEhmfOh0Hn
#
# Time Stamp:Sun Apr 08 08:52:11 +0000 2018
#
# ===================================================<
#
# Tweet Count:28
#
# User Name:SeanLipSyncSock
#
# Tweet:RT @EdKrassen: Someone dies in Trump Tower because the building didn’t have fire sprinklers, and all Trump can do is brag about “how well b…
#
# Time Stamp:Sun Apr 08 08:52:11 +0000 2018
#
# ===================================================<
#
# Tweet Count:29
#
# User Name:LVanSomeren
#
# Tweet:RT @wesley_jordan: According to the @AP, Trump's national security team &amp; military leaders have warned him that pulling out of Syria will c…
#
# Time Stamp:Sun Apr 08 08:52:11 +0000 2018
#
# ===================================================<
#
# Tweet Count:30
#
# User Name:distressedvol
#
# Tweet:1 dead, 4 injured as 120+ firefighters battle blaze at Trump Tower in Manhattan https://t.co/OqCnEe0g1i
#
# Time Stamp:Sun Apr 08 08:52:11 +0000 2018
#
# ===================================================<
#
# Tweet Count:31
#
# User Name:dddaniel059
#
# Tweet:RT @realDonaldTrump: Fire at Trump Tower is out. Very confined (well built building). Firemen (and women) did a great job. THANK YOU!
#
# Time Stamp:Sun Apr 08 08:52:11 +0000 2018
#
# ===================================================<
#
# Tweet Count:32
#
# User Name:glpiman
#
# Tweet:RT @MSNBC: Stormy Daniels' lawyer Michael Avenatti promises a "major announcement" in case against President Trump https://t.co/8RbWiDnhPr
#
# Time Stamp:Sun Apr 08 08:52:12 +0000 2018
#
# ===================================================<
#
# Tweet Count:33
#
# User Name:cboshrun
#
# Tweet:Top story: Trump Tower fire victim ID'd as Todd Brassner, art dealer who sold W… https://t.co/1PEKOjiGou, see more https://t.co/IG5uUAHw8c
#
# Time Stamp:Sun Apr 08 08:52:12 +0000 2018
#
# ===================================================<
#
# Tweet Count:34
#
# User Name:jrbkjrbk
#
# Tweet:RT @DearAuntCrabby: Michael Avenatti Is About To Drop A Bomb On Trump By Revealing Who Threatened Stormy Daniels https://t.co/Mcv3Vigm0q vi…
#
# Time Stamp:Sun Apr 08 08:52:12 +0000 2018
#
# ===================================================<
#
# Tweet Count:35
#
# User Name:Sagopaak
#
# Tweet:1)Jaishal ul Isam was on verge of defeat in #Douma.
#
# 2)Trump announced to pull back American forces.
#
# 3)Saudi, &amp; Pen… https://t.co/YW6WhBriYr
#
# Time Stamp:Sun Apr 08 08:52:11 +0000 2018
#
# ===================================================<
#
# Tweet Count:36
#
# User Name:megaroni61
#
# Tweet:RT @gr8tjude: Regardless of who you dislike you should never wish harm to anyone!
#
#
#
# MENTAL HEALTH COUNSELOR Tweets: “I hope the fire rages”…
#
# Time Stamp:Sun Apr 08 08:52:12 +0000 2018
#
# ===================================================<
#
# Tweet Count:37
#
# User Name:heiressarts
#
# Tweet:REMEMBER when McStain said let's Give Trump fake intel? Trump has #Q and superior military intelligence. Great Decisions. Follow #Qanon
#
# Time Stamp:Sun Apr 08 08:52:12 +0000 2018
#
# ===================================================<
#
# Tweet Count:38
#
# User Name:RWC_News
#
# Tweet:Joy Behar Praises Stormy Daniels As A Feminist Hero, Until Trump’s New Lawyer Gives Her Some Bad News The ladies o https://t.co/giBpWxxP2q
#
# Time Stamp:Sun Apr 08 08:52:13 +0000 2018
#
# ===================================================<
#
# Tweet Count:39
#
# User Name:MLKhemra3
#
# Tweet:RT @MarthaLimKhemra: @realDonaldTrump Make America Most
#
# Insulted Always by thievery of GEN. John Nicholson Rank 4-star of USA, he thieved m…
#
# Time Stamp:Sun Apr 08 08:52:13 +0000 2018
#
# ===================================================<
#
# Tweet Count:40
#
# User Name:Freediver_Doris
#
# Tweet:RT @erinscafe: Reminder: the 50th floor of Trump Tower is actually the 40th floor, because Trump inflated the numbers.
#
#
#
# That’s not a joke,…
#
# Time Stamp:Sun Apr 08 08:52:13 +0000 2018
#
# ===================================================<
#
# Tweet Count:41
#
# User Name:NavySP3
#
# Tweet:RT @Pink_About_it: Imagine a person so hell bent on trump derangement, that he wishes gleeful harm as long as it's a trump supporter, membe…
#
# Time Stamp:Sun Apr 08 08:52:13 +0000 2018
#
# ===================================================<
#
# Tweet Count:42
#
# User Name:Maria_O59
#
# Tweet:RT @TheDweck: A person in his building died and he’s    bragging about the building https://t.co/OKA7Hbf12L
#
# Time Stamp:Sun Apr 08 08:52:13 +0000 2018
#
# ===================================================<
#
# Tweet Count:43
#
# User Name:RhondaRrusse
#
# Tweet:RT @joshgad: When I grow up, I want to be Ivanka’s clothing line. It’s treated better than dreamers, immigrants, gays, transgender troops,…
#
# Time Stamp:Sun Apr 08 08:52:13 +0000 2018
#
# ===================================================<
#
# Tweet Count:44
#
# User Name:baloch_shadan
#
# Tweet:RT @IsraelUSAforevr: 💯Special SHOUT-OUT💯
#
#
#
# We all have to follow this patriot, he supports Trump and the US, he's new here, let's show him s…
#
# Time Stamp:Sun Apr 08 08:52:13 +0000 2018
#
# ===================================================<
#
# Tweet Count:45
#
# User Name:Milvio_Diaz
#
# Tweet:RT @SethAbramson: A man *died*. How is this an appropriate tweet? https://t.co/QIGJt7JVMw
#
# Time Stamp:Sun Apr 08 08:52:13 +0000 2018
#
# ===================================================<
#
# Tweet Count:46
#
# User Name:AZjbc
#
# Tweet:Sounds Like Family Should SUE Him!! What A Twisted Soul !! Makes Me Sick ! @jefferyguterman Will You Be Attending T… https://t.co/WAPHaiA8gA
#
# Time Stamp:Sun Apr 08 08:52:14 +0000 2018
#
# ===================================================<
#
# Tweet Count:47
#
# User Name:TracyMeagher
#
# Tweet:RT @goldengateblond: Remember kids, regulations are bad. https://t.co/hdiuLwHP4n https://t.co/KaeIQCt33n
#
# Time Stamp:Sun Apr 08 08:52:14 +0000 2018
#
# ===================================================<
#
# Tweet Count:48
#
# User Name:NormanGagnon3
#
# Tweet:RT @MKRIZSA50: In 2007 radio interview Trump Jr joked about being invited to the #PlayboyMansion w his pregnant wife...Can you believe the…
#
# Time Stamp:Sun Apr 08 08:52:14 +0000 2018
#
# ===================================================<
#
# Tweet Count:49
#
# User Name:FubsyShabaroon
#
# Tweet:"fake news"
#
#
#
# See? Full Trump. https://t.co/UCQx554YQx
#
# Time Stamp:Sun Apr 08 08:52:14 +0000 2018
#
# ===================================================<
#
# Tweet Count:50
#
# User Name:BretSalzer
#
# Tweet:RT @darionavarro111: Trump has brought nepotism and lawlessness to unprecedented extremes in the federal government. He is now using US tar…
#
# Time Stamp:Sun Apr 08 08:52:14 +0000 2018
#
# ===================================================<
#
# Tweet Count:51
#
# User Name:ShakilDregoon
#
# Tweet:RT @MatthewWolfff: .@CNBC with list of US products affected by China’s tariff response.
#
#
#
# That’s a lot of agriculture, cars, and petroleum p…
#
# Time Stamp:Sun Apr 08 08:52:15 +0000 2018
#
# ===================================================<
#
# Tweet Count:52
#
# User Name:WB_Devitt_III
#
# Tweet:Aye, it's why the Syrian/Russian bombers had the further gall to drop chemical weapons upon civilians...
#
#
#
# As… https://t.co/aL0N1q66lj
#
# Time Stamp:Sun Apr 08 08:52:15 +0000 2018
#
# ===================================================<
#
# Tweet Count:53
#
# User Name:4usa564
#
# Tweet:RT @We_R_TheMedia: It's amazingly sad and pathetic that @ABCNetwork would keep this homophobic, misogynist on air.
#
#
#
# Not funny, Jimmy. Not.…
#
# Time Stamp:Sun Apr 08 08:52:15 +0000 2018
#
# ===================================================<
#
# Tweet Count:54
#
# User Name:valobwai
#
# Tweet:RT @ScottPresler: Please make sure to screenshot anyone celebrating the death from a fire at Trump tower.
#
#
#
# We need to publicly shame this…
#
# Time Stamp:Sun Apr 08 08:52:15 +0000 2018
#
# ===================================================<
#
# Tweet Count:55
#
# User Name:goosebumps_fan
#
# Tweet:RT @cristinalaila1: Someone tell the demonic psychologist @JeffreyGuterman just because he deleted his tweets cheering the Trump Tower fire…
#
# Time Stamp:Sun Apr 08 08:52:15 +0000 2018
#
# ===================================================<
#
# Tweet Count:56
#
# User Name:melimel521
#
# Tweet:RT @HAGOODMANAUTHOR: That's bizarre, a chemical attack in #Syria immediately after #Trump publicly announces he wants to pull out American…
#
# Time Stamp:Sun Apr 08 08:52:15 +0000 2018
#
# ===================================================<
#
# Tweet Count:57
#
# User Name:gelynda18
#
# Tweet:RT @jd_chrissie: Wow Tony La Viña 😱
#
#
#
# When somebody says something nega about NNLY, especially obvious haters, I hope we can let it go. Afte…
#
# Time Stamp:Sun Apr 08 08:52:15 +0000 2018
#
# ===================================================<
#
# Tweet Count:58
#
# User Name:acsadvice
#
# Tweet:RT @wesley_jordan: According to the @AP, Trump's national security team &amp; military leaders have warned him that pulling out of Syria will c…
#
# Time Stamp:Sun Apr 08 08:52:15 +0000 2018
#
# ===================================================<
#
# Tweet Count:59
#
# User Name:toonsmag
#
# Tweet:@POLITICOEurope Like it! We would like to invite you to visit our cartoons.  https://t.co/wIhP0HsH8h
#
# Time Stamp:Sun Apr 08 08:52:15 +0000 2018
#
# ===================================================<
#
# Tweet Count:60
#
# User Name:alt_altright
#
# Tweet:Trump condemns anti-Semitism but can't stop questions - https://t.co/A57FEVHlVw https://t.co/ZlbC8ntThm
#
# Time Stamp:Sun Apr 08 08:52:15 +0000 2018
#
# ===================================================<
#
# Tweet Count:61
#
# User Name:shulin7
#
# Tweet:RT @SiddonsDan3: “All my friends up there in the press, you all know why in your hearts Trump won the Republican nomination. You know why h…
#
# Time Stamp:Sun Apr 08 08:52:15 +0000 2018
#
# ===================================================<
#
# Tweet Count:62
#
# User Name:care_deplorable
#
# Tweet:RT @realDonaldTrump: Fire at Trump Tower is out. Very confined (well built building). Firemen (and women) did a great job. THANK YOU!
#
# Time Stamp:Sun Apr 08 08:52:15 +0000 2018
#
# ===================================================<
#
# Tweet Count:63
#
# User Name:GlasgowStarling
#
# Tweet:RT @mikegalsworthy: Jesus 😞 https://t.co/aY38tM5GbJ
#
# Time Stamp:Sun Apr 08 08:52:16 +0000 2018
#
# ===================================================<
#
# Tweet Count:64
#
# User Name:central_cellar
#
# Tweet:RT @PhilMcCrackin44: American Airlines has ordered 47 Boeing 787 Dreamliners. Cancels their order for Airbus A350’s.
#
# This move was made i…
#
# Time Stamp:Sun Apr 08 08:52:16 +0000 2018
#
# ===================================================<
#
# Tweet Count:65
#
# User Name:MLKhemra3
#
# Tweet:RT @MarthaLimKhemra: @realDonaldTrump Make America Most
#
# Insulted Always by thievery of GEN. John Nicholson Rank 4-star of USA, he thieved m…
#
# Time Stamp:Sun Apr 08 08:52:16 +0000 2018
#
# ===================================================<
#
# Tweet Count:66
#
# User Name:Frances54205009
#
# Tweet:RT @tedlieu: Dear @DHSgov: You know what was the last Administration that was freaked out about the free press and media influencers? The R…
#
# Time Stamp:Sun Apr 08 08:52:17 +0000 2018
#
# ===================================================<
#
# Tweet Count:67
#
# User Name:sinthedetails
#
# Tweet:'There are no consequences!' Screeching Jeanine Pirro blames Republicans for letting Hollywood disrespect Trump https://t.co/ffFTd4wmGM
#
# Time Stamp:Sun Apr 08 08:52:17 +0000 2018
#
# ===================================================<
#
# Tweet Count:68
#
# User Name:jerry_sypek
#
# Tweet:RT @shepley_cheryl: @thebradfordfile @immigrant_legal #Trump doesn't Associate with TRAITOR TRASH*
#
# Time Stamp:Sun Apr 08 08:52:17 +0000 2018
#
# ===================================================<
#
# Tweet Count:69
#
# User Name:Garryinmaine
#
# Tweet:RT @ggreenwald: 40,000 people re-tweeted, and almost 160,000 people "liked," this moronic, plutocratic dreck, fantasizing about a billionai…
#
# Time Stamp:Sun Apr 08 08:52:17 +0000 2018
#
# ===================================================<
#
# Tweet Count:70
#
# User Name:HillObscuresVu
#
# Tweet:RT @dionlisle: We are not being invaded by Mexico. Send the national guard to Puerto Rico to help them get water and power. Maybe to Flint…
#
# Time Stamp:Sun Apr 08 08:52:17 +0000 2018
#
# ===================================================<
#
# Tweet Count:71
#
# User Name:SeanFlanderhijn
#
# Tweet:RT @TomthunkitsMind: Psychiatrists: President Trump 'is a danger to the public, and the international community.' https://t.co/bJYIS7jcNt
#
# Time Stamp:Sun Apr 08 08:52:17 +0000 2018
#
# ===================================================<
#
# Tweet Count:72
#
# User Name:Price7Y
#
# Tweet:RT @Golfinggary5221: Senior #FBI and  #DOJ officials in #Obama administration conspired to illegally exonerate #HillaryClinton in the priva…
#
# Time Stamp:Sun Apr 08 08:52:17 +0000 2018
#
# ===================================================<
#
# Tweet Count:73
#
# User Name:Sympai29
#
# Tweet:RT @realDonaldTrump: Fire at Trump Tower is out. Very confined (well built building). Firemen (and women) did a great job. THANK YOU!
#
# Time Stamp:Sun Apr 08 08:52:17 +0000 2018
#
# ===================================================<
#
# Tweet Count:74
#
# User Name:gracemorrrison
#
# Tweet:RT @TheDweck: A person in his building died and he’s    bragging about the building https://t.co/OKA7Hbf12L
#
# Time Stamp:Sun Apr 08 08:52:17 +0000 2018
#
# ===================================================<
#
# Tweet Count:75
#
# User Name:Daisy49103
#
# Tweet:RT @Golfinggary5221: WHO’S IN CHARGE HERE?Oregon’s Democrat Governor Will Refuse #Trump's Order of #NationalGuard to the Border! #Sedition?…
#
# Time Stamp:Sun Apr 08 08:52:17 +0000 2018
#
# ===================================================<
#
# Tweet Count:76
#
# User Name:BlueHumanity
#
# Tweet:RT @BlueHumanity: Trump Tower (a well built building) has a 2d fire within 3 months.
#
#
#
# Meanwhile, Trump's plan to burn down the government,…
#
# Time Stamp:Sun Apr 08 08:52:17 +0000 2018
#
# ===================================================<
#
# Tweet Count:77
#
# User Name:ryrysven
#
# Tweet:RT @RepDonBeyer: “It is grossly irresponsible to continue allowing Jared Kushner such direct influence over American foreign policy” https:…
#
# Time Stamp:Sun Apr 08 08:52:17 +0000 2018
#
# ===================================================<
